# %% [markdown]
# # Event co-reference

# %%
import pandas as pd

# %%
event_type = 'mass shooting'
lang = 'nl'

path = f"task_data/{event_type.replace(' ', '-')}_{lang}.csv"

# %%
df = pd.read_csv(path)

# %%
new_df = df[df['label'] == 0]
new_df
# Out:
#      Unnamed: 0  label                              title0  \
# 694         694      0            Schietincident Ridderhof
# 695         695      0            Schietincident Ridderhof
# 696         696      0            Schietincident Ridderhof
# 697         697      0            Schietincident Ridderhof
# 698         698      0            Schietincident Ridderhof
# ..          ...    ...                                 ...
# 985         985      0  Duizenden bij herdenking in Alphen
# 986         986      0  Duizenden bij herdenking in Alphen
# 987         987      0  Duizenden bij herdenking in Alphen
# 988         988      0  Duizenden bij herdenking in Alphen
# 989         989      0  Duizenden bij herdenking in Alphen
#
#                                                  text0  inc_id0  \
# 694  Schietincident Ridderhof.\n\nSchietincident Ri...  Q473866
# 695  Schietincident Ridderhof.\n\nSchietincident Ri...  Q473866
# 696  Schietincident Ridderhof.\n\nSchietincident Ri...  Q473866
# 697  Schietincident Ridderhof.\n\nSchietincident Ri...  Q473866
# 698  Schietincident Ridderhof.\n\nSchietincident Ri...  Q473866
# ..                                                 ...      ...
# 985  Duizenden bij herdenking in Alphen.\n\n» Inwon...  Q473866
# 986  Duizenden bij herdenking in Alphen.\n\n» Inwon...  Q473866
# 987  Duizenden bij herdenking in Alphen.\n\n» Inwon...  Q473866
# 988  Duizenden bij herdenking in Alphen.\n\n» Inwon...  Q473866
# 989  Duizenden bij herdenking in Alphen.\n\n» Inwon...  Q473866
#
#                                                 title1  \
# 694  Gökmen T. schreef in briefje uit naam van Alla...
# 695  Rutte: vlaggen op overheidsgebouwen vandaag ha...
# 696  Extra alertheid bij moskeeën en stations in Br...
# 697  Rutte en Grapperhaus leggen bloemen bij aansla...
# 698  Eerste reactie Rutte en Grapperhaus op schietp...
# ..                                                 ...
# 985                  Aanslag Utrecht eist vierde leven
# 986  Zwarte dag in Utrecht: dit gebeurde er op de d...
# 987  Levenslange gevangenisstraf geëist voor aansla...
# 988  Verplichte rechtsbijstand voor verdachte schie...
# 989  Moskee in Zaandam beveiligd na schietpartij in...
#
#                                                  text1  inc_id1  \
# 694  G&#246;kmen T. schreef in briefje uit naam van...  Q473866
# 695  Rutte: vlaggen op overheidsgebouwen vandaag ha...  Q473866
# 696  Extra alertheid bij moskee&#235;n en stations ...  Q473866
# 697  Rutte en Grapperhaus leggen bloemen bij aansla...  Q473866
# 698  Eerste reactie Rutte en Grapperhaus op schietp...  Q473866
# ..                                                 ...      ...
# 985  Aanslag Utrecht eist vierde leven.\n\nUpdateEe...  Q473866
# 986  Zwarte dag in Utrecht: dit gebeurde er op de d...  Q473866
# 987  Levenslange gevangenisstraf ge&#235;ist voor a...  Q473866
# 988  Verplichte rechtsbijstand voor verdachte schie...  Q473866
# 989  Moskee in Zaandam beveiligd na schietpartij in...  Q473866
#
#      shared_frames  shared_elements  total_overlap
# 694              0                0              0
# 695              1                3              4
# 696              0                0              0
# 697              0                0              0
# 698              3                7             10
# ..             ...              ...            ...
# 985              2                6              8
# 986              2                6              8
# 987              4               12             16
# 988              0                0              0
# 989              3               11             14
#
# [296 rows x 11 columns]

# %%
# example prompt

target_row = 987

prompt_start = "I am going to show you two texts called text1 and text2. Please tell me whether these two texts refer to the same incident."

for i, row in new_df.iterrows():
    if i == target_row:
        t1 = row['text0']
        t2 = row['text1']

        print(prompt_start)
        print()
        print(f'text1: {t1}')
        print()
        print(f'text2: {t2}')
# Out:
# I am going to show you two texts called text1 and text2. Please tell me whether these two texts refer to the same incident.
#
# text1: Duizenden bij herdenking in Alphen.
#
# » Inwoners van Alphen aan den Rijn herdenken de slachtoffers van 9 april met bloemen en kaarsen NOS NOS
# Bij winkelcentrum de Ridderhof in Alphen aan den Rijn zijn de slachtoffers van de schietpartij van gisteren herdacht. Bij het incident kwamen zeven mensen om het leven, onder wie de schutter die zelfmoord pleegde.
# Bij de bijeenkomst waren waarnemend burgemeester Eenhoorn, minister Opstelten van Veiligheid en premier Rutte aanwezig. De bijeenkomst duurde niet lang, zo'n vijftien minuten. Daarna gingen Eenhoorn, Opstelten en Rutte naar de plek waar de bloemen zijn neergelegd. Bij het winkelcentrum waar de schietpartij plaatsvond, waren zesduizend mensen bijeengekomen.
# Eenhoorn sprak van een 'zwarte dag' na een zonnig begin. Hij prees speciaal de hulpverleners, de 'helden van de Ridderhof', die met gevaar voor eigen leven mensen van de schutter weg probeerden te krijgen. Eén hulpverlener kwam hierbij zelf om het leven.
# Ook had Eenhoorn aandacht voor de Syrische dichter die is omgekomen. Hij was zijn land uitgevlucht en is nu in Alphen omgekomen bij een zinloze schietpartij.
# Hij zei dat zijn gemeente sterker uit dit drama zal komen, maar het nooit zal vergeten. "Het is veel erger dan wij denken. Niet alleen voor de slachtoffers, maar voor de hele maatschappij."
# Diepe wonden
# Minister-president Mark Rutte zei dat sommige dingen niet in woorden zijn te vatten. "Dit is een drama dat diepe wonden heeft geslagen in de samenleving van Alphen." Hij bedankte alle hulpverleners. Rutte zei ook nog dat de koningin intens, intens meeleeft. "Heel Nederland staat om jullie heen", zei de premier.
# Na afloop van de toespraken was er een moment stilte.
# De herdenking wordt rechtstreeks uitgezonden op Nederland 2, Radio 1 en Journaal24.
#
#
# text2: Levenslange gevangenisstraf ge&#235;ist voor aanslag in en rond Utrechtse tram.
#
# Het Openbaar Ministerie heeft vandaag een levenslange gevangenisstraf geëist tegen de verdachte van de aanslag in en rond de tram in Utrecht op 18 maart vorig jaar. De 38-jarige Utrechter wordt verantwoordelijk gehouden voor de moord op vier mensen, poging moord op drie mensen en bedreiging met een terroristisch misdrijf van zeventien mensen. De officieren van justitie achten het bewezen dat de man handelde met een terroristisch oogmerk. Aanslag 18 maart 2019 Op 18 maart 2019 ontvangen de hulpdiensten rond kwart voor elf ’s ochtends een groot aantal meldingen van een schietpartij op het 24 Oktoberpl