# %% [markdown]
# # Event co-reference task
#
# News articles often report on incidents (e.g. a terrorist attack or a natural disaster). Different articles may report on the same incident, but approach it from different perspectives. For instance, an article may have been written right after the event occured, several weeks after the event occured (when new information is uncovered or follow-up events occur) or even years after the event (reflecting on its implications). There is a high degree of linguistic variation in how such events are expressed in text. It is very difficult for automatic systems to recognize if two texts are about the same indicident or not (i.e. perform event coreference).
#
# In the course of the Dutch FrameNet project, we have collected texts about real-world incidents using information about indicdents from Wikidata and Wikipedia. Through these resources, we were able to compile corpora of news articles that all report on the same indicent. The indicents can further be categorized in event types (e.g. mass shooting, royal wedding, etc.). This approach provides us with a challenging event-coreference dataset; we have texts reporting on the same incident written at different times after the event (and potentially containing a high degree of variation in referring to the same indicent) and texts about different incidents of the same type, thus potentially containing a high degree of similar expressions and even ambiguity.
#
# Many of our texts have manually been annotated in terms of semantic roles (as represented in FrameNet). In contrast to traditional SRL, we annotate frames on the level of the entire document instead of on the level of sentences. In addition, we capture information about whether a frame expresses information about target incident we are focusing on.
#
# For this hackathon, we propose a binary event-coreference task containing three subtasks:
#
#
# * Subtask 1: Are the two texts about the same incident? (gold: structured data information - target incidents)
# * Subtask 2: Provide an explanation of your answer giving evidence from the text (gold: frame annotations)
# * Subtask 3: Perform event linking: Name the incident or incidents the texts are about (gold: structured data information - target incidents)
#
# Subtask 3 may seem particularly uncrealistic for "a humble language model". However, given that models are being trained on virtually all data on the internet, it could be interesting to explore how much of this information the model captures and how reliably it can produce it.
#
# Data: to be made available soon.

# %%
import json
import pandas as pd
import os
from lxml import etree as et
from collections import defaultdict
import itertools

import utils_structured
import utils_docs
import utils_naf
import utils_task

# %%
path_data = '../dfn-data-cleaning/data-headlines/unstructured'
path_structured = f'../DFNDataReleases/structured/'

# %%
type2inc, type2label, inc2label, inc2lang2doc, annotation_status_dict, inc2str = utils_structured.load_structured_data(path_structured)

# %%
# Overview
# table: event type, inc, annotated docs, not annotated docs, not found

lang = 'en'
df_en = utils_structured.generate_overview(lang, type2inc, type2label, inc2label, inc2lang2doc, annotation_status_dict, inc2str)
lang = 'nl'
df_nl = utils_structured.generate_overview(lang, type2inc, type2label, inc2label, inc2lang2doc, annotation_status_dict, inc2str)
# Out:
# table written to: overview_en.csv
# table written to: overview_nl.csv

# %%
df_shooting = df_en[df_en['typeID'] == 'Q63442071']
print(len(df_shooting))
# Out:
# 17

# %%
df_en_higher10 = df_en[df_en['annotated-manual'] > 9]
df_en_higher10
# Out:
#                    type     typeID  \
# 77        mass shooting  Q21480300
# 100       mass shooting  Q21480300
# 108       mass shooting  Q21480300
# 123       mass shooting  Q21480300
# 127       mass shooting  Q21480300
# 136       mass shooting  Q21480300
# 139       mass shooting  Q21480300
# 140       mass shooting  Q21480300
# 150       mass shooting  Q21480300
# 154       mass shooting  Q21480300
# 162          legal case   Q2334719
# 180          legal case   Q2334719
# 191          legal case   Q2334719
# 224       royal wedding  Q63442071
# 227       royal wedding  Q63442071
# 231       royal wedding  Q63442071
# 234  aircraft shootdown   Q6539177
# 417      music festival    Q868557
#
#                                                    inc       incID  \
# 77                               2016 Hesston shooting   Q23012840
# 100                           2011 Seal Beach shooting    Q4443728
# 108                            2014 Fort Hood shooting   Q16016666
# 123                              2019 Utrecht shooting   Q62090804
# 127                           2015 Bamako hotel attack   Q21516923
# 136                       2015 San Bernardino shooting   Q21613643
# 139                          2016 Citronelle homicides   Q27629584
# 140                           2016 Kalamazoo shootings   Q22910769
# 150                         2015 Chattanooga shootings   Q20671234
# 154           2015 Charleston, South Carolina shooting   Q20154675
# 162                            Enumclaw horse sex case  Q101209661
# 180                      Cambodian–Thai border dispute     Q168329
# 191                          2015 FIFA corruption case   Q19984977
# 224  wedding of Charles, Prince of Wales, and Lady ...    Q1094155
# 227          wedding of Prince Harry and Meghan Markle   Q43890449
# 231    wedding of Princess Eugenie and Jack Brooksbank   Q48815612
# 234                        Malaysia Airlines Flight 17   Q17374096
# 417                       Eurovision Song Contest 2020   Q30973589
#
#        inc_time  total  file not found  annotated-manual  file exists  \
# 77   2016-02-25     15             NaN              14.0          1.0
# 100  2011-10-12     12             NaN              12.0          NaN
# 108  2014-04-02     12             NaN              12.0          NaN
# 123  0001-01-01     22             5.0              17.0          NaN
# 127  2015-11-20     14             2.0              12.0          NaN
# 136  2015-12-02     15             NaN              14.0          NaN
# 139  2016-08-20     14             1.0              12.0          NaN
# 140  2016-02-20     19             2.0              16.0          NaN
# 150  2015-07-16     13             NaN              13.0          NaN
# 154  2015-06-17     15             NaN              15.0          NaN
# 162  2005-07-01     14             NaN              14.0          NaN
# 180  2011-12-15     59             7.0              43.0          NaN
# 191  2015-01-01     82            15.0              62.0          NaN
# 224  1981-07-29     45            10.0              35.0          NaN
# 227  2018-05-19    103            64.0              37.0          NaN
# 231  2018-10-12     46             NaN              45.0          NaN
# 234  0001-01-01    183            54.0             129.0          NaN
# 417  2020-01-01    277           235.0              38.0          NaN
#
#      annotated-system  annotated-deprecated
# 77                NaN                   NaN
# 100               NaN                   NaN
# 108               NaN                   NaN
# 123               NaN                   NaN
# 127               NaN                   NaN
# 136               1.0                   NaN
# 139               1.0                   NaN
# 140               1.0                   NaN
# 150               NaN                   NaN
# 154               NaN                   NaN
# 162               NaN                   NaN
# 180               9.0                   NaN
# 191               5.0                   NaN
# 224               NaN                   NaN
# 227               2.0                   NaN
# 231               1.0                   NaN
# 234               NaN                   NaN
# 417               4.0                   NaN

# %%
df_nl_higher10 = df_nl[df_nl['annotated-manual'] > 9]
df_nl_higher10
# Out:
#                         type     typeID  \
# 74             mass shooting  Q21480300
# 123            mass shooting  Q21480300
# 210  Eurovision Song Contest       Q276
# 215         disease outbreak   Q3241045
# 234       aircraft shootdown   Q6539177
# 417           music festival    Q868557
# 420           music festival    Q868557
#
#                                             inc       incID    inc_time  \
# 74   Alphen aan den Rijn shopping mall shooting     Q473866  2011-04-09
# 123                       2019 Utrecht shooting   Q62090804  0001-01-01
# 210                     2021 Dutch curfew riots  Q105077032  0001-01-01
# 215        COVID-19 pandemic in the Netherlands   Q86756826  0001-01-01
# 234                 Malaysia Airlines Flight 17   Q17374096  0001-01-01
# 417                Eurovision Song Contest 2020   Q30973589  2020-01-01
# 420                Eurovision Song Contest 2019    Q9095390  0001-01-01
#
#      total  file not found  file exists  annotated-manual
# 74      12             2.0          NaN              10.0
# 123     49             6.0          NaN              43.0
# 210     43             4.0          1.0              38.0
# 215    333           318.0          2.0              13.0
# 234    135            26.0          NaN             109.0
# 417     37             9.0          2.0              26.0
# 420     12             2.0          NaN              10.0

# %%
# # selected types

types_selected = ['legal case', 'mass shooting', 'royal wedding']
lang = 'en'
for type_selected in types_selected:
    utils_task.create_event_type_data(type_selected, df_en, path_data, lang, inc2label, inc2lang2doc, inc2str, min_doc = 10)
# Out:
# Incident info: Enumclaw horse sex case Q101209661
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2005-07-01T00:00:00UTC | 2005-07-01T00:00:00UTC']}
#
# Incident info: Cambodian–Thai border dispute Q168329
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q869 | Thailand'], 'sem:hasTimeStamp': ['2011-12-15T00:00:00UTC | 2011-12-15T00:00:00UTC']}
#
# Incident info: 2015 FIFA corruption case Q19984977
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q39 | Switzerland'], 'sem:hasTimeStamp': ['2015-01-01T00:00:00UTC | 2015-01-01T00:00:00UTC']}
#
# Incident info: Enumclaw horse sex case Q101209661
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2005-07-01T00:00:00UTC | 2005-07-01T00:00:00UTC']}
#
# Incident info: Cambodian–Thai border dispute Q168329
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q869 | Thailand'], 'sem:hasTimeStamp': ['2011-12-15T00:00:00UTC | 2011-12-15T00:00:00UTC']}
#
# Incident info: Enumclaw horse sex case Q101209661
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2005-07-01T00:00:00UTC | 2005-07-01T00:00:00UTC']}
#
# Incident info: 2015 FIFA corruption case Q19984977
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q39 | Switzerland'], 'sem:hasTimeStamp': ['2015-01-01T00:00:00UTC | 2015-01-01T00:00:00UTC']}
#
# Incident info: Cambodian–Thai border dispute Q168329
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q869 | Thailand'], 'sem:hasTimeStamp': ['2011-12-15T00:00:00UTC | 2011-12-15T00:00:00UTC']}
#
# Incident info: 2015 FIFA corruption case Q19984977
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q39 | Switzerland'], 'sem:hasTimeStamp': ['2015-01-01T00:00:00UTC | 2015-01-01T00:00:00UTC']}
#
# Created dataset for event type: legal case
# Written dataset to: task_data/legal-case_en.csv
# Frame info written to: task_data/legal-case_en_frames.json
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2016 Hesston shooting Q23012840
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-25T00:00:00UTC | 2016-02-25T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2011 Seal Beach shooting Q4443728
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2011-10-12T00:00:00UTC | 2011-10-12T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2014 Fort Hood shooting Q16016666
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2014-04-02T00:00:00UTC | 2014-04-02T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2015 Bamako hotel attack Q21516923
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q912 | Mali'], 'sem:hasTimeStamp': ['2015-11-20T00:00:00UTC | 2015-11-20T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2015 San Bernardino shooting Q21613643
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-12-02T00:00:00UTC | 2015-12-02T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2016 Citronelle homicides Q27629584
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-08-20T00:00:00UTC | 2016-08-20T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2016 Kalamazoo shootings Q22910769
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2016-02-20T00:00:00UTC | 2016-02-20T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Incident info: 2015 Chattanooga shootings Q20671234
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-07-16T00:00:00UTC | 2015-07-16T00:00:00UTC']}
#
# Incident info: 2015 Charleston, South Carolina shooting Q20154675
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q30 | United States of America'], 'sem:hasTimeStamp': ['2015-06-17T00:00:00UTC | 2015-06-17T00:00:00UTC']}
#
# Created dataset for event type: mass shooting
# Written dataset to: task_data/mass-shooting_en.csv
# Frame info written to: task_data/mass-shooting_en_frames.json
# Incident info: wedding of Charles, Prince of Wales, and Lady Diana Spencer Q1094155
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['1981-07-29T00:00:00UTC | 1981-07-29T00:00:00UTC']}
#
# Incident info: wedding of Prince Harry and Meghan Markle Q43890449
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-05-19T00:00:00UTC | 2018-05-19T00:00:00UTC']}
#
# Incident info: wedding of Princess Eugenie and Jack Brooksbank Q48815612
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-10-12T00:00:00UTC | 2018-10-12T00:00:00UTC']}
#
# Incident info: wedding of Charles, Prince of Wales, and Lady Diana Spencer Q1094155
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['1981-07-29T00:00:00UTC | 1981-07-29T00:00:00UTC']}
#
# Incident info: wedding of Prince Harry and Meghan Markle Q43890449
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-05-19T00:00:00UTC | 2018-05-19T00:00:00UTC']}
#
# Incident info: wedding of Charles, Prince of Wales, and Lady Diana Spencer Q1094155
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['1981-07-29T00:00:00UTC | 1981-07-29T00:00:00UTC']}
#
# Incident info: wedding of Princess Eugenie and Jack Brooksbank Q48815612
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-10-12T00:00:00UTC | 2018-10-12T00:00:00UTC']}
#
# Incident info: wedding of Prince Harry and Meghan Markle Q43890449
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-05-19T00:00:00UTC | 2018-05-19T00:00:00UTC']}
#
# Incident info: wedding of Princess Eugenie and Jack Brooksbank Q48815612
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q145 | United Kingdom'], 'sem:hasTimeStamp': ['2018-10-12T00:00:00UTC | 2018-10-12T00:00:00UTC']}
#
# Created dataset for event type: royal wedding
# Written dataset to: task_data/royal-wedding_en.csv
# Frame info written to: task_data/royal-wedding_en_frames.json

# %%
types_selected = ['mass shooting', 'music festival']
lang = 'nl'
for type_selected in types_selected:
    utils_task.create_event_type_data(type_selected, df_nl, path_data, lang, inc2label, inc2lang2doc, inc2str, min_doc = 10)
# Out:
# Incident info: Alphen aan den Rijn shopping mall shooting Q473866
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q29999 | Kingdom of the Netherlands'], 'sem:hasTimeStamp': ['2011-04-09T00:00:00UTC | 2011-04-09T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Incident info: Alphen aan den Rijn shopping mall shooting Q473866
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q29999 | Kingdom of the Netherlands'], 'sem:hasTimeStamp': ['2011-04-09T00:00:00UTC | 2011-04-09T00:00:00UTC']}
#
# Incident info: 2019 Utrecht shooting Q62090804
# {}
#
# Created dataset for event type: mass shooting
# Written dataset to: task_data/mass-shooting_nl.csv
# Frame info written to: task_data/mass-shooting_nl_frames.json
# Incident info: Eurovision Song Contest 2020 Q30973589
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q55 | Netherlands'], 'sem:hasTimeStamp': ['2020-01-01T00:00:00UTC | 2020-01-01T00:00:00UTC']}
#
# Incident info: Eurovision Song Contest 2019 Q9095390
# {}
#
# Incident info: Eurovision Song Contest 2020 Q30973589
# {'sem:hasPlace': ['http://www.wikidata.org/entity/Q55 | Netherlands'], 'sem:hasTimeStamp': ['2020-01-01T00:00:00UTC | 2020-01-01T00:00:00UTC']}
#
# Incident info: Eurovision Song Contest 2019 Q9095390
# {}
#
# Created dataset for event type: music festival
# Written dataset to: task_data/music-festival_nl.csv
# Frame info written to: task_data/music-festival_nl_frames.json
